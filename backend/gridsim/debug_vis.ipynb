# %%
import backend.gridsim.visualization as v
import inspect

print("Loaded visualization.py from:", v.__file__)
print("Functions found:", [name for name, obj in inspect.getmembers(v) if inspect.isfunction(obj)])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import backend.gridsim.visualization as v
#       2 import inspect
#       4 print("Loaded visualization.py from:", v.__file__)
#
# ModuleNotFoundError: No module named 'backend'

# %%
python backend/gridsim/debug_vis.py
# Out:
#   Cell In[2], line 1
#     python backend/gridsim/debug_vis.py
#            ^
# SyntaxError: invalid syntax
